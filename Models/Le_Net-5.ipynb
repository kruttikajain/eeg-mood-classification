# %% [markdown]
# <a href="https://colab.research.google.com/github/omkarpat/eeg-mood-classification/blob/master/Models/Le_Net-5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Colab settings/mount
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/My\ Drive/CSE\ 240/Project/Data/spectrogram_images/
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/CSE 240/Project/Data/spectrogram_images

# %%
import os
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, StratifiedKFold

# %tensorflow_version 2.x
import tensorflow
print(tensorflow.__version__)
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, Convolution2D, Conv2D, MaxPooling2D, Lambda, GlobalMaxPooling2D, GlobalAveragePooling2D, BatchNormalization, Activation, AveragePooling2D, Concatenate, SeparableConv2D, MaxPooling3D, Conv3D, DepthwiseConv2D
from tensorflow.keras.models import model_from_json
# Out:
# TensorFlow 2.x selected.
# 2.1.0

# %%
base_path = "."
concentration_data_array = None
relaxed_data_array = None
print("loading data from .npy files...")
for filename in os.listdir(base_path):
  if "concentration_array_updated_spectrograms" in filename and "final" not in filename:
    print(filename)
    concentration_data_array = np.concatenate((concentration_data_array, np.load(filename))) if concentration_data_array is not None else np.load(filename)
  if "relaxed_array_updated_spectrograms" in filename:
    print(filename)
    relaxed_data_array = np.concatenate((relaxed_data_array, np.load(filename))) if relaxed_data_array is not None else np.load(filename)
print(concentration_data_array.shape, relaxed_data_array.shape)
print(len(concentration_data_array), len(relaxed_data_array))
# Out:
# loading data from .npy files...
# concentration_array_updated_spectrograms_1.npy
# concentration_array_updated_spectrograms_2.npy
# concentration_array_updated_spectrograms_3.npy
# concentration_array_updated_spectrograms_4.npy
# concentration_array_updated_spectrograms_5.npy
# concentration_array_updated_spectrograms_6.npy
# relaxed_array_updated_spectrograms_1.npy
# relaxed_array_updated_spectrograms_2.npy
# relaxed_array_updated_spectrograms_3.npy
# relaxed_array_updated_spectrograms_4.npy
# relaxed_array_updated_spectrograms_5.npy
# relaxed_array_updated_spectrograms_final.npy
# (2160, 29, 43, 42) (2124, 29, 43, 42)
# 2160 2124

# %%
X = np.concatenate((relaxed_data_array, concentration_data_array))
Y = np.concatenate((np.zeros((len(relaxed_data_array),1)),np.ones((len(concentration_data_array),1))))
print(X.shape, Y.shape)
relaxed_data_array, concentration_data_array = None, None
# Out:
# (4284, 29, 43, 42) (4284, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.15, random_state=42)
X, Y = None, None
folds = list(StratifiedKFold(n_splits=10, shuffle=True, random_state=1).split(X_train, y_train))
#X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.15, random_state=42)
#print(X_train.shape, X_test.shape, X_valid.shape, y_train.shape, y_test.shape, y_valid.shape)

# %%
model_name = "LeNet"
def get_model():
  model = Sequential()

  model.add(Conv2D(filters=6, kernel_size=(3, 3), activation='relu', input_shape=(29, 43, 42)))
  model.add(AveragePooling2D())

  model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu'))
  model.add(AveragePooling2D())

  model.add(Flatten())

  model.add(Dense(units=120, activation='relu'))

  model.add(Dense(units=84, activation='relu'))

  model.add(Dense(units=10, activation = 'softmax')) 

  # model.add(Conv2D(64, kernel_size=5, strides=(1,1), padding='valid', activation='relu', input_shape = (29, 43, 42)))
  # model.add(Conv2D(128, kernel_size=3, activation='relu'))
  # model.add(MaxPooling2D(pool_size=(3, 3)))

  # model.add(Conv2D(256, kernel_size=3, strides=(1,1), padding='valid', activation='relu'))
  # model.add(Conv2D(512, kernel_size=2, activation='relu'))
  # model.add(MaxPooling2D(pool_size=(2, 2)))
  
  # model.add(Flatten())
  # model.add(Dense(100, activation='relu'))
  # model.add(Dense(50, activation='relu'))
  # model.add(Dense(1, activation='sigmoid'))
  
  #sgd = optimizers.SGD(lr=0.000001, momentum=0.7, decay=1e-6)
  #model.compile(optimizer=sgd, loss='binary_crossentropy', metrics=['accuracy'])
  
  adm = optimizers.Adam(lr=0.0001, decay=1e-6)
  model.compile(optimizer=adm, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
  return model
  model.summary()

# %%
filepath= model_name + "-weights-improvement-{epoch:02d}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
model2 = get_model()
for j, (train_idx, val_idx) in enumerate(folds):
  print('\nFold ',j)
  X_train_cv = X_train[train_idx]
  y_train_cv = y_train[train_idx]
  X_valid_cv = X_train[val_idx]
  y_valid_cv= y_train[val_idx]
  # checkpoint
  model2.fit(X_train_cv, y_train_cv, validation_data=(X_valid_cv, y_valid_cv), epochs=10, batch_size=32, callbacks=callbacks_list, shuffle=True)
score = model2.evaluate(X_test,y_test)
print("Test set metrics: %s: %.2f%%" % (model2.metrics_names[1], score[1]*100))
model2_json = model2.to_json()
with open(model_name + ".json", "w") as json_file:
    json_file.write(model2_json)
# serialize weights to HDF5
model2.save_weights(model_name + ".h5")
print("Saved model %s to disk" % (model_name))
# Out:
# Fold  0
# Train on 3276 samples, validate on 365 samples
# Epoch 1/10
# 3232/3276 [============================>.] - ETA: 0s - loss: 7.9673 - accuracy: 0.4759
# Epoch 00001: accuracy improved from -inf to 0.47466, saving model to LeNet-weights-improvement-01.hdf5
# 3276/3276 [==============================] - 8s 2ms/sample - loss: 7.9018 - accuracy: 0.4747 - val_loss: 2.6015 - val_accuracy: 0.5260
# Epoch 2/10
# 3232/3276 [============================>.] - ETA: 0s - loss: 2.3172 - accuracy: 0.5084
# Epoch 00002: accuracy improved from 0.47466 to 0.50946, saving model to LeNet-weights-improvement-02.hdf5
# 3276/3276 [==============================] - 1s 366us/sample - loss: 2.3072 - accuracy: 0.5095 - val_loss: 1.8795 - val_accuracy: 0.5260
# Epoch 3/10
# 3136/3276 [===========================>..] - ETA: 0s - loss: 2.0027 - accuracy: 0.5252
# Epoch 00003: accuracy improved from 0.50946 to 0.52198, saving model to LeNet-weights-improvement-03.hdf5
# 3276/3276 [==============================] - 1s 374us/sample - loss: 1.9890 - accuracy: 0.5220 - val_loss: 1.9903 - val_accuracy: 0.5014
# Epoch 4/10
# 3136/3276 [===========================>..] - ETA: 0s - loss: 1.7340 - accuracy: 0.5261
# Epoch 00004: accuracy improved from 0.52198 to 0.52595, saving model to LeNet-weights-improvement-04.hdf5
# 3276/3276 [==============================] - 1s 376us/sample - loss: 1.7382 - accuracy: 0.5259 - val_loss: 1.5266 - val_accuracy: 0.5123
# Epoch 5/10
# 3264/3276 [============================>.] - ETA: 0s - loss: 1.6125 - accuracy: 0.5463
# Epoch 00005: accuracy improved from 0.52595 to 0.54548, saving model to LeNet-weights-improvement-05.hdf5
# 3276/3276 [==============================] - 1s 370us/sample - loss: 1.6148 - accuracy: 0.5455 - val_loss: 1.4316 - val_accuracy: 0.5370
# Epoch 6/10
# 3264/3276 [============================>.] - ETA: 0s - loss: 1.4061 - accuracy: 0.5282
# Epoch 00006: accuracy did not improve from 0.54548
# 3276/3276 [==============================] - 1s 341us/sample - loss: 1.4021 - accuracy: 0.5296 - val_loss: 1.4415 - val_accuracy: 0.5205
# Epoch 7/10
# 3168/3276 [============================>.] - ETA: 0s - loss: 1.3207 - accuracy: 0.5436
# Epoch 00007: accuracy did not improve from 0.54548
# 3276/3276 [==============================] - 1s 332us/sample - loss: 1.3272 - accuracy: 0.5415 - val_loss: 1.2204 - val_accuracy: 0.5288
# Epoch 8/10
# 3200/3276 [============================>.] - ETA: 0s - loss: 1.2790 - accuracy: 0.5450
# Epoch 00008: accuracy did not improve from 0.54548
# 3276/3276 [==============================] - 1s 328us/sample - loss: 1.2770 - accuracy: 0.5443 - val_loss: 1.1443 - val_accuracy: 0.5288
# Epoch 9/10
# 3200/3276 [============================>.] - ETA: 0s - loss: 1.1395 - accuracy: 0.5319
# Epoch 00009: accuracy did not improve from 0.54548
# 3276/3276 [==============================] - 1s 333us/sample - loss: 1.1369 - accuracy: 0.5330 - val_loss: 1.1370 - val_accuracy: 0.5397
# Epoch 10/10
# 3136/3276 [===========================>..] - ETA: 0s - loss: 1.0588 - accuracy: 0.5469
# Epoch 00010: accuracy improved from 0.54548 to 0.54670, saving model to LeNet-weights-improvement-10.hdf5
# 3276/3276 [==============================] - 1s 348us/sample - loss: 1.0556 - accuracy: 0.5467 - val_loss: 1.2515 - val_accuracy: 0.5068
#
# Fold  1
# Train on 3277 samples, validate on 364 samples
# Epoch 1/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 1.0408 - accuracy: 0.5438
# Epoch 00001: accuracy did not improve from 0.54670
# 3277/3277 [==============================] - 1s 338us/sample - loss: 1.0403 - accuracy: 0.5438 - val_loss: 0.8887 - val_accuracy: 0.5604
# Epoch 2/10
# 3232/3277 [============================>.] - ETA: 0s - loss: 0.9775 - accuracy: 0.5418
# Epoch 00002: accuracy did not improve from 0.54670
# 3277/3277 [==============================] - 1s 323us/sample - loss: 0.9757 - accuracy: 0.5438 - val_loss: 0.9631 - val_accuracy: 0.5467
# Epoch 3/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.9228 - accuracy: 0.5438
# Epoch 00003: accuracy did not improve from 0.54670
# 3277/3277 [==============================] - 1s 320us/sample - loss: 0.9238 - accuracy: 0.5438 - val_loss: 0.8787 - val_accuracy: 0.5137
# Epoch 4/10
# 3104/3277 [===========================>..] - ETA: 0s - loss: 0.8930 - accuracy: 0.5448
# Epoch 00004: accuracy did not improve from 0.54670
# 3277/3277 [==============================] - 1s 319us/sample - loss: 0.8974 - accuracy: 0.5413 - val_loss: 0.8789 - val_accuracy: 0.5467
# Epoch 5/10
# 3200/3277 [============================>.] - ETA: 0s - loss: 0.8470 - accuracy: 0.5547
# Epoch 00005: accuracy improved from 0.54670 to 0.55417, saving model to LeNet-weights-improvement-05.hdf5
# 3277/3277 [==============================] - 1s 398us/sample - loss: 0.8491 - accuracy: 0.5542 - val_loss: 0.8693 - val_accuracy: 0.5302
# Epoch 6/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.8365 - accuracy: 0.5475
# Epoch 00006: accuracy did not improve from 0.55417
# 3277/3277 [==============================] - 1s 323us/sample - loss: 0.8366 - accuracy: 0.5481 - val_loss: 0.8603 - val_accuracy: 0.5275
# Epoch 7/10
# 3104/3277 [===========================>..] - ETA: 0s - loss: 0.8154 - accuracy: 0.5528
# Epoch 00007: accuracy did not improve from 0.55417
# 3277/3277 [==============================] - 1s 321us/sample - loss: 0.8147 - accuracy: 0.5523 - val_loss: 0.8374 - val_accuracy: 0.5275
# Epoch 8/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.7892 - accuracy: 0.5582
# Epoch 00008: accuracy improved from 0.55417 to 0.55783, saving model to LeNet-weights-improvement-08.hdf5
# 3277/3277 [==============================] - 1s 336us/sample - loss: 0.7906 - accuracy: 0.5578 - val_loss: 0.9250 - val_accuracy: 0.5192
# Epoch 9/10
# 3232/3277 [============================>.] - ETA: 0s - loss: 0.8178 - accuracy: 0.5693
# Epoch 00009: accuracy improved from 0.55783 to 0.56698, saving model to LeNet-weights-improvement-09.hdf5
# 3277/3277 [==============================] - 1s 338us/sample - loss: 0.8242 - accuracy: 0.5670 - val_loss: 0.8598 - val_accuracy: 0.5110
# Epoch 10/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.7793 - accuracy: 0.5653
# Epoch 00010: accuracy did not improve from 0.56698
# 3277/3277 [==============================] - 1s 321us/sample - loss: 0.7799 - accuracy: 0.5648 - val_loss: 0.8540 - val_accuracy: 0.5220
#
# Fold  2
# Train on 3277 samples, validate on 364 samples
# Epoch 1/10
# 3104/3277 [===========================>..] - ETA: 0s - loss: 0.7737 - accuracy: 0.5599
# Epoch 00001: accuracy did not improve from 0.56698
# 3277/3277 [==============================] - 1s 322us/sample - loss: 0.7749 - accuracy: 0.5587 - val_loss: 0.7229 - val_accuracy: 0.5632
# Epoch 2/10
# 3232/3277 [============================>.] - ETA: 0s - loss: 0.7332 - accuracy: 0.5600
# Epoch 00002: accuracy did not improve from 0.56698
# 3277/3277 [==============================] - 1s 323us/sample - loss: 0.7329 - accuracy: 0.5615 - val_loss: 0.7332 - val_accuracy: 0.5577
# Epoch 3/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.7378 - accuracy: 0.5754
# Epoch 00003: accuracy improved from 0.56698 to 0.57553, saving model to LeNet-weights-improvement-03.hdf5
# 3277/3277 [==============================] - 1s 391us/sample - loss: 0.7372 - accuracy: 0.5755 - val_loss: 0.7380 - val_accuracy: 0.5687
# Epoch 4/10
# 3200/3277 [============================>.] - ETA: 0s - loss: 0.7356 - accuracy: 0.5688
# Epoch 00004: accuracy did not improve from 0.57553
# 3277/3277 [==============================] - 1s 326us/sample - loss: 0.7357 - accuracy: 0.5691 - val_loss: 0.7370 - val_accuracy: 0.5495
# Epoch 5/10
# 3104/3277 [===========================>..] - ETA: 0s - loss: 0.7140 - accuracy: 0.5706
# Epoch 00005: accuracy did not improve from 0.57553
# 3277/3277 [==============================] - 1s 323us/sample - loss: 0.7145 - accuracy: 0.5709 - val_loss: 0.7107 - val_accuracy: 0.5549
# Epoch 6/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.7213 - accuracy: 0.5812
# Epoch 00006: accuracy improved from 0.57553 to 0.58102, saving model to LeNet-weights-improvement-06.hdf5
# 3277/3277 [==============================] - 1s 338us/sample - loss: 0.7217 - accuracy: 0.5810 - val_loss: 0.7192 - val_accuracy: 0.5522
# Epoch 7/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.6987 - accuracy: 0.5839
# Epoch 00007: accuracy improved from 0.58102 to 0.58346, saving model to LeNet-weights-improvement-07.hdf5
# 3277/3277 [==============================] - 1s 343us/sample - loss: 0.6996 - accuracy: 0.5835 - val_loss: 0.7575 - val_accuracy: 0.5687
# Epoch 8/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.6990 - accuracy: 0.5800
# Epoch 00008: accuracy did not improve from 0.58346
# 3277/3277 [==============================] - 1s 321us/sample - loss: 0.6986 - accuracy: 0.5798 - val_loss: 0.6992 - val_accuracy: 0.5742
# Epoch 9/10
# 3232/3277 [============================>.] - ETA: 0s - loss: 0.6758 - accuracy: 0.5910
# Epoch 00009: accuracy improved from 0.58346 to 0.59078, saving model to LeNet-weights-improvement-09.hdf5
# 3277/3277 [==============================] - 1s 420us/sample - loss: 0.6767 - accuracy: 0.5908 - val_loss: 0.7284 - val_accuracy: 0.5385
# Epoch 10/10
# 3104/3277 [===========================>..] - ETA: 0s - loss: 0.6746 - accuracy: 0.5983
# Epoch 00010: accuracy improved from 0.59078 to 0.60055, saving model to LeNet-weights-improvement-10.hdf5
# 3277/3277 [==============================] - 1s 397us/sample - loss: 0.6720 - accuracy: 0.6005 - val_loss: 0.7231 - val_accuracy: 0.5742
#
# Fold  3
# Train on 3277 samples, validate on 364 samples
# Epoch 1/10
# 3232/3277 [============================>.] - ETA: 0s - loss: 0.6677 - accuracy: 0.6108
# Epoch 00001: accuracy improved from 0.60055 to 0.61031, saving model to LeNet-weights-improvement-01.hdf5
# 3277/3277 [==============================] - 1s 401us/sample - loss: 0.6676 - accuracy: 0.6103 - val_loss: 0.7496 - val_accuracy: 0.5275
# Epoch 2/10
# 3232/3277 [============================>.] - ETA: 0s - loss: 0.6544 - accuracy: 0.6163
# Epoch 00002: accuracy improved from 0.61031 to 0.61672, saving model to LeNet-weights-improvement-02.hdf5
# 3277/3277 [==============================] - 1s 411us/sample - loss: 0.6546 - accuracy: 0.6167 - val_loss: 0.6818 - val_accuracy: 0.5824
# Epoch 3/10
# 3168/3277 [============================>.] - ETA: 0s - loss: 0.6712 - accuracy: 0.6061
# Epoch 00003: accuracy did not improve from 0.61672
# 3277/3277 [==============================] - 1s 330us/sample - loss: 0.6754 - accuracy: 0.6021 - val_loss: 0.7139 - val_accuracy: 0.5852
# Epoch 4/10
# 3104/3277 [===========================>..] - ETA: 0s - loss: 0.6538 - accuracy: 0.6140
# Epoch 00004: accuracy did not improve from 0.61672
# 3277/3277 [==============================] - 1s 320us/sample - loss: 0.6540 - accuracy: 0.6125 - val_loss: 0.7501 - val_accuracy: 0.5522
# Epoch 5/10
# 3104/3277 [===========================>..] - ETA: 0s - loss: 0.6536 - accuracy: 0.6102
# Epoch 00005: accuracy did not improve from 0.61672
# 3277/3277 [==============================] - 1s 318us/sample - loss: 0.6521 - accuracy: 0.6094 - val_loss: 0.7079 - val_accuracy: 0.5495
# Epoch 6/10
# 3232/3277 [============================>.] - ETA: 0s - loss: 0.6401 - accuracy: 0.6228
# Epoch 00006: accuracy improved from 0.61672 to 0.62252, saving model to LeNet-weights-improvement-06.hdf5
# 3277/3277 [==============================] - 1s 396us/sample - loss: 0.6406 - accuracy: 0.6225 - val_loss: 0.7025 - val_accuracy: 0.5632
# Epoch 7/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.6230 - accuracy: 0.6363
# Epoch 00007: accuracy improved from 0.62252 to 0.63564, saving model to LeNet-weights-improvement-07.hdf5
# 3277/3277 [==============================] - 1s 394us/sample - loss: 0.6237 - accuracy: 0.6356 - val_loss: 0.7111 - val_accuracy: 0.5467
# Epoch 8/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.6174 - accuracy: 0.6501
# Epoch 00008: accuracy improved from 0.63564 to 0.65029, saving model to LeNet-weights-improvement-08.hdf5
# 3277/3277 [==============================] - 1s 388us/sample - loss: 0.6172 - accuracy: 0.6503 - val_loss: 0.7498 - val_accuracy: 0.5742
# Epoch 9/10
# 3104/3277 [===========================>..] - ETA: 0s - loss: 0.6246 - accuracy: 0.6408
# Epoch 00009: accuracy did not improve from 0.65029
# 3277/3277 [==============================] - 1s 322us/sample - loss: 0.6238 - accuracy: 0.6430 - val_loss: 0.7596 - val_accuracy: 0.5714
# Epoch 10/10
# 3200/3277 [============================>.] - ETA: 0s - loss: 0.6241 - accuracy: 0.6334
# Epoch 00010: accuracy did not improve from 0.65029
# 3277/3277 [==============================] - 1s 324us/sample - loss: 0.6228 - accuracy: 0.6344 - val_loss: 0.7642 - val_accuracy: 0.5440
#
# Fold  4
# Train on 3277 samples, validate on 364 samples
# Epoch 1/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.6306 - accuracy: 0.6363
# Epoch 00001: accuracy did not improve from 0.65029
# 3277/3277 [==============================] - 1s 325us/sample - loss: 0.6303 - accuracy: 0.6363 - val_loss: 0.6026 - val_accuracy: 0.6126
# Epoch 2/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.6151 - accuracy: 0.6458
# Epoch 00002: accuracy did not improve from 0.65029
# 3277/3277 [==============================] - 1s 325us/sample - loss: 0.6156 - accuracy: 0.6460 - val_loss: 0.6148 - val_accuracy: 0.6319
# Epoch 3/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.6135 - accuracy: 0.6520
# Epoch 00003: accuracy improved from 0.65029 to 0.65273, saving model to LeNet-weights-improvement-03.hdf5
# 3277/3277 [==============================] - 1s 414us/sample - loss: 0.6128 - accuracy: 0.6527 - val_loss: 0.6238 - val_accuracy: 0.6044
# Epoch 4/10
# 3232/3277 [============================>.] - ETA: 0s - loss: 0.6046 - accuracy: 0.6572
# Epoch 00004: accuracy improved from 0.65273 to 0.65670, saving model to LeNet-weights-improvement-04.hdf5
# 3277/3277 [==============================] - 1s 398us/sample - loss: 0.6054 - accuracy: 0.6567 - val_loss: 0.6113 - val_accuracy: 0.6071
# Epoch 5/10
# 3232/3277 [============================>.] - ETA: 0s - loss: 0.6026 - accuracy: 0.6566
# Epoch 00005: accuracy did not improve from 0.65670
# 3277/3277 [==============================] - 1s 323us/sample - loss: 0.6027 - accuracy: 0.6564 - val_loss: 0.6172 - val_accuracy: 0.6154
# Epoch 6/10
# 3232/3277 [============================>.] - ETA: 0s - loss: 0.5974 - accuracy: 0.6584
# Epoch 00006: accuracy improved from 0.65670 to 0.65883, saving model to LeNet-weights-improvement-06.hdf5
# 3277/3277 [==============================] - 1s 392us/sample - loss: 0.5968 - accuracy: 0.6588 - val_loss: 0.6619 - val_accuracy: 0.5659
# Epoch 7/10
# 3232/3277 [============================>.] - ETA: 0s - loss: 0.6031 - accuracy: 0.6547
# Epoch 00007: accuracy did not improve from 0.65883
# 3277/3277 [==============================] - 1s 329us/sample - loss: 0.6033 - accuracy: 0.6543 - val_loss: 0.6334 - val_accuracy: 0.5989
# Epoch 8/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.5852 - accuracy: 0.6697
# Epoch 00008: accuracy improved from 0.65883 to 0.66982, saving model to LeNet-weights-improvement-08.hdf5
# 3277/3277 [==============================] - 1s 392us/sample - loss: 0.5850 - accuracy: 0.6698 - val_loss: 0.6545 - val_accuracy: 0.5907
# Epoch 9/10
# 3104/3277 [===========================>..] - ETA: 0s - loss: 0.5807 - accuracy: 0.6736
# Epoch 00009: accuracy improved from 0.66982 to 0.67470, saving model to LeNet-weights-improvement-09.hdf5
# 3277/3277 [==============================] - 1s 398us/sample - loss: 0.5806 - accuracy: 0.6747 - val_loss: 0.6467 - val_accuracy: 0.6044
# Epoch 10/10
# 3104/3277 [===========================>..] - ETA: 0s - loss: 0.5686 - accuracy: 0.6856
# Epoch 00010: accuracy improved from 0.67470 to 0.68538, saving model to LeNet-weights-improvement-10.hdf5
# 3277/3277 [==============================] - 1s 400us/sample - loss: 0.5701 - accuracy: 0.6854 - val_loss: 0.7358 - val_accuracy: 0.5769
#
# Fold  5
# Train on 3277 samples, validate on 364 samples
# Epoch 1/10
# 3200/3277 [============================>.] - ETA: 0s - loss: 0.5833 - accuracy: 0.6750
# Epoch 00001: accuracy did not improve from 0.68538
# 3277/3277 [==============================] - 1s 327us/sample - loss: 0.5829 - accuracy: 0.6756 - val_loss: 0.5802 - val_accuracy: 0.6923
# Epoch 2/10
# 3104/3277 [===========================>..] - ETA: 0s - loss: 0.5711 - accuracy: 0.6888
# Epoch 00002: accuracy improved from 0.68538 to 0.68630, saving model to LeNet-weights-improvement-02.hdf5
# 3277/3277 [==============================] - 1s 389us/sample - loss: 0.5720 - accuracy: 0.6863 - val_loss: 0.5943 - val_accuracy: 0.6813
# Epoch 3/10
# 3200/3277 [============================>.] - ETA: 0s - loss: 0.5623 - accuracy: 0.6844
# Epoch 00003: accuracy did not improve from 0.68630
# 3277/3277 [==============================] - 1s 330us/sample - loss: 0.5610 - accuracy: 0.6857 - val_loss: 0.5940 - val_accuracy: 0.6676
# Epoch 4/10
# 3232/3277 [============================>.] - ETA: 0s - loss: 0.5550 - accuracy: 0.6909
# Epoch 00004: accuracy improved from 0.68630 to 0.69301, saving model to LeNet-weights-improvement-04.hdf5
# 3277/3277 [==============================] - 1s 388us/sample - loss: 0.5535 - accuracy: 0.6930 - val_loss: 0.6097 - val_accuracy: 0.6813
# Epoch 5/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.5660 - accuracy: 0.6872
# Epoch 00005: accuracy did not improve from 0.69301
# 3277/3277 [==============================] - 1s 327us/sample - loss: 0.5664 - accuracy: 0.6872 - val_loss: 0.6464 - val_accuracy: 0.6484
# Epoch 6/10
# 3104/3277 [===========================>..] - ETA: 0s - loss: 0.5431 - accuracy: 0.7075
# Epoch 00006: accuracy improved from 0.69301 to 0.70766, saving model to LeNet-weights-improvement-06.hdf5
# 3277/3277 [==============================] - 1s 384us/sample - loss: 0.5420 - accuracy: 0.7077 - val_loss: 0.5952 - val_accuracy: 0.6703
# Epoch 7/10
# 3200/3277 [============================>.] - ETA: 0s - loss: 0.5312 - accuracy: 0.7153
# Epoch 00007: accuracy improved from 0.70766 to 0.71620, saving model to LeNet-weights-improvement-07.hdf5
# 3277/3277 [==============================] - 1s 400us/sample - loss: 0.5315 - accuracy: 0.7162 - val_loss: 0.6095 - val_accuracy: 0.6648
# Epoch 8/10
# 3232/3277 [============================>.] - ETA: 0s - loss: 0.5269 - accuracy: 0.7153
# Epoch 00008: accuracy did not improve from 0.71620
# 3277/3277 [==============================] - 1s 327us/sample - loss: 0.5271 - accuracy: 0.7150 - val_loss: 0.6191 - val_accuracy: 0.6484
# Epoch 9/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.5265 - accuracy: 0.7267
# Epoch 00009: accuracy improved from 0.71620 to 0.72719, saving model to LeNet-weights-improvement-09.hdf5
# 3277/3277 [==============================] - 1s 375us/sample - loss: 0.5264 - accuracy: 0.7272 - val_loss: 0.6187 - val_accuracy: 0.6429
# Epoch 10/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.5258 - accuracy: 0.7258
# Epoch 00010: accuracy did not improve from 0.72719
# 3277/3277 [==============================] - 1s 324us/sample - loss: 0.5258 - accuracy: 0.7260 - val_loss: 0.6162 - val_accuracy: 0.6621
#
# Fold  6
# Train on 3277 samples, validate on 364 samples
# Epoch 1/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.5434 - accuracy: 0.7108
# Epoch 00001: accuracy did not improve from 0.72719
# 3277/3277 [==============================] - 1s 329us/sample - loss: 0.5438 - accuracy: 0.7104 - val_loss: 0.5572 - val_accuracy: 0.7115
# Epoch 2/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.5207 - accuracy: 0.7264
# Epoch 00002: accuracy did not improve from 0.72719
# 3277/3277 [==============================] - 1s 326us/sample - loss: 0.5211 - accuracy: 0.7266 - val_loss: 0.5031 - val_accuracy: 0.7143
# Epoch 3/10
# 3232/3277 [============================>.] - ETA: 0s - loss: 0.5267 - accuracy: 0.7308
# Epoch 00003: accuracy improved from 0.72719 to 0.73146, saving model to LeNet-weights-improvement-03.hdf5
# 3277/3277 [==============================] - 1s 380us/sample - loss: 0.5269 - accuracy: 0.7315 - val_loss: 0.5024 - val_accuracy: 0.7253
# Epoch 4/10
# 3200/3277 [============================>.] - ETA: 0s - loss: 0.5044 - accuracy: 0.7434
# Epoch 00004: accuracy improved from 0.73146 to 0.74489, saving model to LeNet-weights-improvement-04.hdf5
# 3277/3277 [==============================] - 1s 407us/sample - loss: 0.5024 - accuracy: 0.7449 - val_loss: 0.5052 - val_accuracy: 0.7198
# Epoch 5/10
# 3200/3277 [============================>.] - ETA: 0s - loss: 0.5117 - accuracy: 0.7303
# Epoch 00005: accuracy did not improve from 0.74489
# 3277/3277 [==============================] - 1s 328us/sample - loss: 0.5125 - accuracy: 0.7293 - val_loss: 0.5283 - val_accuracy: 0.7060
# Epoch 6/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.5024 - accuracy: 0.7457
# Epoch 00006: accuracy improved from 0.74489 to 0.74611, saving model to LeNet-weights-improvement-06.hdf5
# 3277/3277 [==============================] - 1s 391us/sample - loss: 0.5028 - accuracy: 0.7461 - val_loss: 0.5295 - val_accuracy: 0.7143
# Epoch 7/10
# 3200/3277 [============================>.] - ETA: 0s - loss: 0.4920 - accuracy: 0.7484
# Epoch 00007: accuracy improved from 0.74611 to 0.74825, saving model to LeNet-weights-improvement-07.hdf5
# 3277/3277 [==============================] - 1s 381us/sample - loss: 0.4921 - accuracy: 0.7482 - val_loss: 0.5435 - val_accuracy: 0.7308
# Epoch 8/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.4726 - accuracy: 0.7601
# Epoch 00008: accuracy improved from 0.74825 to 0.76045, saving model to LeNet-weights-improvement-08.hdf5
# 3277/3277 [==============================] - 1s 395us/sample - loss: 0.4727 - accuracy: 0.7605 - val_loss: 0.5420 - val_accuracy: 0.6951
# Epoch 9/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.4687 - accuracy: 0.7665
# Epoch 00009: accuracy improved from 0.76045 to 0.76686, saving model to LeNet-weights-improvement-09.hdf5
# 3277/3277 [==============================] - 1s 395us/sample - loss: 0.4686 - accuracy: 0.7669 - val_loss: 0.5313 - val_accuracy: 0.7115
# Epoch 10/10
# 3232/3277 [============================>.] - ETA: 0s - loss: 0.4621 - accuracy: 0.7778
# Epoch 00010: accuracy improved from 0.76686 to 0.77876, saving model to LeNet-weights-improvement-10.hdf5
# 3277/3277 [==============================] - 1s 404us/sample - loss: 0.4614 - accuracy: 0.7788 - val_loss: 0.5632 - val_accuracy: 0.6648
#
# Fold  7
# Train on 3277 samples, validate on 364 samples
# Epoch 1/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.4667 - accuracy: 0.7623
# Epoch 00001: accuracy did not improve from 0.77876
# 3277/3277 [==============================] - 1s 326us/sample - loss: 0.4671 - accuracy: 0.7617 - val_loss: 0.4560 - val_accuracy: 0.7940
# Epoch 2/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.4617 - accuracy: 0.7693
# Epoch 00002: accuracy did not improve from 0.77876
# 3277/3277 [==============================] - 1s 321us/sample - loss: 0.4621 - accuracy: 0.7690 - val_loss: 0.5021 - val_accuracy: 0.7143
# Epoch 3/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.4473 - accuracy: 0.7822
# Epoch 00003: accuracy improved from 0.77876 to 0.78181, saving model to LeNet-weights-improvement-03.hdf5
# 3277/3277 [==============================] - 1s 385us/sample - loss: 0.4475 - accuracy: 0.7818 - val_loss: 0.4890 - val_accuracy: 0.7473
# Epoch 4/10
# 3168/3277 [============================>.] - ETA: 0s - loss: 0.4421 - accuracy: 0.7825
# Epoch 00004: accuracy did not improve from 0.78181
# 3277/3277 [==============================] - 1s 331us/sample - loss: 0.4439 - accuracy: 0.7806 - val_loss: 0.4843 - val_accuracy: 0.7473
# Epoch 5/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.4420 - accuracy: 0.7858
# Epoch 00005: accuracy improved from 0.78181 to 0.78639, saving model to LeNet-weights-improvement-05.hdf5
# 3277/3277 [==============================] - 1s 410us/sample - loss: 0.4415 - accuracy: 0.7864 - val_loss: 0.5214 - val_accuracy: 0.7088
# Epoch 6/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.4165 - accuracy: 0.8079
# Epoch 00006: accuracy improved from 0.78639 to 0.80745, saving model to LeNet-weights-improvement-06.hdf5
# 3277/3277 [==============================] - 1s 390us/sample - loss: 0.4174 - accuracy: 0.8074 - val_loss: 0.5488 - val_accuracy: 0.6868
# Epoch 7/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.4211 - accuracy: 0.7963
# Epoch 00007: accuracy did not improve from 0.80745
# 3277/3277 [==============================] - 1s 326us/sample - loss: 0.4219 - accuracy: 0.7962 - val_loss: 0.5019 - val_accuracy: 0.7253
# Epoch 8/10
# 3232/3277 [============================>.] - ETA: 0s - loss: 0.4059 - accuracy: 0.8128
# Epoch 00008: accuracy improved from 0.80745 to 0.81507, saving model to LeNet-weights-improvement-08.hdf5
# 3277/3277 [==============================] - 1s 395us/sample - loss: 0.4042 - accuracy: 0.8151 - val_loss: 0.4589 - val_accuracy: 0.7665
# Epoch 9/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.3991 - accuracy: 0.8186
# Epoch 00009: accuracy improved from 0.81507 to 0.81813, saving model to LeNet-weights-improvement-09.hdf5
# 3277/3277 [==============================] - 1s 389us/sample - loss: 0.3998 - accuracy: 0.8181 - val_loss: 0.4882 - val_accuracy: 0.7418
# Epoch 10/10
# 3168/3277 [============================>.] - ETA: 0s - loss: 0.4013 - accuracy: 0.8084
# Epoch 00010: accuracy did not improve from 0.81813
# 3277/3277 [==============================] - 1s 325us/sample - loss: 0.3994 - accuracy: 0.8108 - val_loss: 0.5115 - val_accuracy: 0.7225
#
# Fold  8
# Train on 3277 samples, validate on 364 samples
# Epoch 1/10
# 3200/3277 [============================>.] - ETA: 0s - loss: 0.4042 - accuracy: 0.8128
# Epoch 00001: accuracy did not improve from 0.81813
# 3277/3277 [==============================] - 1s 331us/sample - loss: 0.4033 - accuracy: 0.8135 - val_loss: 0.3611 - val_accuracy: 0.8571
# Epoch 2/10
# 3104/3277 [===========================>..] - ETA: 0s - loss: 0.3984 - accuracy: 0.8128
# Epoch 00002: accuracy did not improve from 0.81813
# 3277/3277 [==============================] - 1s 328us/sample - loss: 0.4002 - accuracy: 0.8111 - val_loss: 0.3552 - val_accuracy: 0.8379
# Epoch 3/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.3885 - accuracy: 0.8195
# Epoch 00003: accuracy improved from 0.81813 to 0.81935, saving model to LeNet-weights-improvement-03.hdf5
# 3277/3277 [==============================] - 1s 379us/sample - loss: 0.3888 - accuracy: 0.8193 - val_loss: 0.3732 - val_accuracy: 0.8407
# Epoch 4/10
# 3232/3277 [============================>.] - ETA: 0s - loss: 0.3778 - accuracy: 0.8301
# Epoch 00004: accuracy improved from 0.81935 to 0.83094, saving model to LeNet-weights-improvement-04.hdf5
# 3277/3277 [==============================] - 1s 407us/sample - loss: 0.3769 - accuracy: 0.8309 - val_loss: 0.4016 - val_accuracy: 0.8104
# Epoch 5/10
# 3200/3277 [============================>.] - ETA: 0s - loss: 0.3844 - accuracy: 0.8141
# Epoch 00005: accuracy did not improve from 0.83094
# 3277/3277 [==============================] - 1s 328us/sample - loss: 0.3846 - accuracy: 0.8145 - val_loss: 0.4256 - val_accuracy: 0.8132
# Epoch 6/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.3424 - accuracy: 0.8597
# Epoch 00006: accuracy improved from 0.83094 to 0.85963, saving model to LeNet-weights-improvement-06.hdf5
# 3277/3277 [==============================] - 1s 391us/sample - loss: 0.3426 - accuracy: 0.8596 - val_loss: 0.4121 - val_accuracy: 0.7830
# Epoch 7/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.3374 - accuracy: 0.8581
# Epoch 00007: accuracy did not improve from 0.85963
# 3277/3277 [==============================] - 1s 326us/sample - loss: 0.3368 - accuracy: 0.8584 - val_loss: 0.3880 - val_accuracy: 0.8214
# Epoch 8/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.3399 - accuracy: 0.8536
# Epoch 00008: accuracy did not improve from 0.85963
# 3277/3277 [==============================] - 1s 326us/sample - loss: 0.3399 - accuracy: 0.8538 - val_loss: 0.4181 - val_accuracy: 0.7940
# Epoch 9/10
# 3232/3277 [============================>.] - ETA: 0s - loss: 0.3170 - accuracy: 0.8682
# Epoch 00009: accuracy improved from 0.85963 to 0.86848, saving model to LeNet-weights-improvement-09.hdf5
# 3277/3277 [==============================] - 1s 390us/sample - loss: 0.3165 - accuracy: 0.8685 - val_loss: 0.4376 - val_accuracy: 0.7830
# Epoch 10/10
# 3136/3277 [===========================>..] - ETA: 0s - loss: 0.3142 - accuracy: 0.8680
# Epoch 00010: accuracy did not improve from 0.86848
# 3277/3277 [==============================] - 1s 327us/sample - loss: 0.3140 - accuracy: 0.8679 - val_loss: 0.3937 - val_accuracy: 0.8242
#
# Fold  9
# Train on 3277 samples, validate on 364 samples
# Epoch 1/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.3343 - accuracy: 0.8578
# Epoch 00001: accuracy did not improve from 0.86848
# 3277/3277 [==============================] - 1s 324us/sample - loss: 0.3344 - accuracy: 0.8575 - val_loss: 0.3081 - val_accuracy: 0.8846
# Epoch 2/10
# 3232/3277 [============================>.] - ETA: 0s - loss: 0.3221 - accuracy: 0.8608
# Epoch 00002: accuracy did not improve from 0.86848
# 3277/3277 [==============================] - 1s 326us/sample - loss: 0.3224 - accuracy: 0.8599 - val_loss: 0.3052 - val_accuracy: 0.8709
# Epoch 3/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.3034 - accuracy: 0.8771
# Epoch 00003: accuracy improved from 0.86848 to 0.87702, saving model to LeNet-weights-improvement-03.hdf5
# 3277/3277 [==============================] - 1s 383us/sample - loss: 0.3035 - accuracy: 0.8770 - val_loss: 0.3021 - val_accuracy: 0.8736
# Epoch 4/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.3033 - accuracy: 0.8707
# Epoch 00004: accuracy did not improve from 0.87702
# 3277/3277 [==============================] - 1s 327us/sample - loss: 0.3036 - accuracy: 0.8703 - val_loss: 0.3115 - val_accuracy: 0.8654
# Epoch 5/10
# 3200/3277 [============================>.] - ETA: 0s - loss: 0.2851 - accuracy: 0.8834
# Epoch 00005: accuracy improved from 0.87702 to 0.88435, saving model to LeNet-weights-improvement-05.hdf5
# 3277/3277 [==============================] - 1s 400us/sample - loss: 0.2843 - accuracy: 0.8843 - val_loss: 0.3193 - val_accuracy: 0.8489
# Epoch 6/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.2997 - accuracy: 0.8750
# Epoch 00006: accuracy did not improve from 0.88435
# 3277/3277 [==============================] - 1s 320us/sample - loss: 0.2993 - accuracy: 0.8755 - val_loss: 0.3128 - val_accuracy: 0.8599
# Epoch 7/10
# 3104/3277 [===========================>..] - ETA: 0s - loss: 0.2651 - accuracy: 0.8930
# Epoch 00007: accuracy improved from 0.88435 to 0.89228, saving model to LeNet-weights-improvement-07.hdf5
# 3277/3277 [==============================] - 1s 388us/sample - loss: 0.2660 - accuracy: 0.8923 - val_loss: 0.3062 - val_accuracy: 0.8544
# Epoch 8/10
# 3104/3277 [===========================>..] - ETA: 0s - loss: 0.2529 - accuracy: 0.9046
# Epoch 00008: accuracy improved from 0.89228 to 0.90235, saving model to LeNet-weights-improvement-08.hdf5
# 3277/3277 [==============================] - 1s 383us/sample - loss: 0.2558 - accuracy: 0.9023 - val_loss: 0.3274 - val_accuracy: 0.8352
# Epoch 9/10
# 3264/3277 [============================>.] - ETA: 0s - loss: 0.2528 - accuracy: 0.8971
# Epoch 00009: accuracy did not improve from 0.90235
# 3277/3277 [==============================] - 1s 322us/sample - loss: 0.2537 - accuracy: 0.8962 - val_loss: 0.3444 - val_accuracy: 0.8352
# Epoch 10/10
# 3104/3277 [===========================>..] - ETA: 0s - loss: 0.2508 - accuracy: 0.9034
# Epoch 00010: accuracy improved from 0.90235 to 0.90327, saving model to LeNet-weights-improvement-10.hdf5
# 3277/3277 [==============================] - 1s 392us/sample - loss: 0.2519 - accuracy: 0.9033 - val_loss: 0.3678 - val_accuracy: 0.8214
# 643/643 [==============================] - 0s 281us/sample - loss: 1.2507 - accuracy: 0.5443
# Test set metrics: accuracy: 54.43%
# Saved model LeNet to disk

# %%
# load json and create model
json_file = open(model_name+ '.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights(model_name + ".h5")
print("Loaded model from disk")

# evaluate loaded model on test data
loaded_model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
score = loaded_model.evaluate(X_test,y_test, verbose=0)
print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))
# Out:
# Loaded model from disk
# accuracy: 54.43%
