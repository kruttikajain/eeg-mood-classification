# %% [markdown]
# # parsing files using pyedflib

# %%
import pyedflib
import numpy as np
import os

# %%
file_name = os.path.join('S001E01.edf')
f = pyedflib.EdfReader(file_name)
n = f.signals_in_file
signal_labels = f.getSignalLabels()
sigbufs = np.zeros((n, f.getNSamples()[0]))
for i in np.arange(n):
    sigbufs[i, :] = f.readSignal(i)

# %%
sigbufs.shape
# Out:
# (14, 46080)

# %%
print(sigbufs)
# Out:
# [[-60.77776776 -56.74816648 -50.03216434 ... -80.30583551 -82.88891325
#   -86.5052221 ]
#  [  0.86504852   2.36749975   2.36749975 ...  94.16011504  93.15848089
#    89.58121607]
#  [-10.81986313 -10.81986313  -8.72961089 ...  32.77682628  32.77682628
#    30.68657404]
#  ...
#  [-12.86438938 -14.92102361 -11.83607227 ...  52.2587146   49.69886136
#    45.59653245]
#  [ -8.83074553  -9.85306024  -4.72738576 ...  55.78659506  53.22023259
#    49.11687283]
#  [-17.12349508 -19.19973266 -17.12349508 ... -17.12349508 -18.12316503
#   -20.19940261]]

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(1, figsize=(80, 40))
for i in range(14):
    x = np.array([j for j in range(46080)])
    y = np.array(sigbufs[i])
    plt.plot(x,y)
plt.show()
#plt.savefig("eeg.png")

# %% [markdown]
# # Feature extraction using pyeeg

# %%
import pyeeg

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as md
